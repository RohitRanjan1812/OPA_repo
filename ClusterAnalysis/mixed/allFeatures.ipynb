# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_pickle(r'D:\Py_Prjs\OPA_repo\ClusterAnalysis\KMeans\Data\df_allInfo_clean.pkl')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 503 entries, A to ON
# Data columns (total 75 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   heldPercentInstitutions       503 non-null    float64
#  1   ebitdaMargins                 503 non-null    float64
#  2   grossProfits                  503 non-null    float64
#  3   recommendationKey             503 non-null    object
#  4   operatingMargins              503 non-null    float64
#  5   grossMargins                  503 non-null    float64
#  6   profitMargins                 503 non-null    float64
#  7   industry                      503 non-null    object
#  8   shortName                     503 non-null    object
#  9   country                       503 non-null    object
#  10  revenuePerShare               503 non-null    float64
#  11  exchange                      503 non-null    object
# ...

# %%
df_numeric = df.select_dtypes(include=['float64'])
df_cat = df.select_dtypes(include=['object'])
cnt_num = df_numeric.isnull().sum()
cnt_cat = df_cat.isnull().sum()
X_num = df_numeric.fillna(df_numeric.median())
X_cat = df_cat.fillna(df_cat.mode())
sc = MinMaxScaler()
X_num_scaled = pd.DataFrame(sc.fit_transform(X_num), columns=X_num.columns, index=X_num.index)
#X_cat_scaled = pd.DataFrame(sc.fit_transform(X_cat), columns=X_cat.columns, index=X_cat.index)

# %%
X_cat
# Out:
#        recommendationKey                          industry  \
# symbol
# A                    buy            Diagnostics & Research
# AAL                 hold                          Airlines
# AAP                  buy                  Specialty Retail
# AAPL                 buy              Consumer Electronics
# ABBV                 buy        Drug Manufacturers—General
# ...                  ...                               ...
# LEN                  buy          Residential Construction
# CBOE                 buy  Financial Data & Stock Exchanges
# DLR                  buy                    REIT—Specialty
# IQV                  buy            Diagnostics & Research
# ON                   buy                    Semiconductors
#
#                             shortName        country exchange           city  \
# symbol
# A          Agilent Technologies, Inc.  United States      NYQ    Santa Clara
# AAL     American Airlines Group, Inc.  United States      NMS     Fort Worth
# ...
